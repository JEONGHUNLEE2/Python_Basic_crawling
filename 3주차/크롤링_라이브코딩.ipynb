# %%
#개발자 도구에서 elements에서 옆옆에 화살표모양 클릭!
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
browser = webdriver.Chrome('c:/informs/chromedriver.exe')
#browser = webdriver.Chrome('./chromedriver.exe') 현재 쥬피터노트북 파일 위치 내

# %%
url = "https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1"
browser.get(url)

# %%
html = browser.page_source

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
# 
channel_list = soup.select('태그정보')
len(channel_list) # 100개

# %%
#channel_list = soup.select('tr')  102개
#channel_list = soup.select('tbody > tr') 101개
#channel_list = soup.select('table > tbody > tr') 101개
channel_list = soup.select('form > table > tbody > tr') 
len(channel_list) # 100개

#구조를 모를 때 
#channel_list = soup.select('tr')[1:-1]
# Out:
# 100

# %%
#채널 1개 뭉치 지정하기 --> 내가 원하는 정보 추출 
channel = channel_list[0] #마지막꺼 
title = channel.select('h1 > a')[0].text.strip() #select 형태는 무조건 list 그래서 [0]넣어줌, 그래야 .text 사용 가능
len(title) #1개 
print(title)
# Out:
# BLACKPINK

# %%
channel = channel_list[0] #마지막꺼 

title = channel.select('h1 > a')[0].text.strip()


category = channel.select('p.category')[0].text #태그명이 p 이면서 class 속성값이 category인 태그 다 찾아줘 
#category = channel.select('h1 > p') #태그명 h1 바로 아래에 있는 태그명 p 인 태그 다 찾아줘
#category = channel.select('.category') #class속성값이 categoty인 태그 다 찾아줘

subscriber = channel.select('.subscriber_cnt')
view = channel.select('.view_cnt')
#video = channel.select('')

len(category)
print(category)
print(subscriber)
print(view)
# Out:
# [음악/댄스/가수]
#
#
# [<td class="subscriber_cnt">5660만</td>]
# [<td class="view_cnt">148억2534만</td>]

# %%
for channel in channel_list:
    
    title = channel.select('h1 > a')[0].text.strip()
    category = channel.select('p.category')[0].text.strip()
    print(title, category)
# Out:
# BLACKPINK [음악/댄스/가수]
# Big Hit Labels [음악/댄스/가수]
# BANGTANTV [음악/댄스/가수]
# Boram Tube Vlog [보람튜브 브이로그] [키즈/어린이]
# SMTOWN [음악/댄스/가수]
# 1MILLION Dance Studio [음악/댄스/가수]
# 1theK (원더케이) [음악/댄스/가수]
# JYP Entertainment [음악/댄스/가수]
# ArianaGrandeVevo [음악/댄스/가수]
# Mnet K-POP [음악/댄스/가수]
# JFlaMusic [음악/댄스/가수]
# NBA [미분류]
# KBS WORLD TV [TV/방송]
# officialpsy [음악/댄스/가수]
# BIGBANG [음악/댄스/가수]
# CNN [뉴스/정치/사회]
# Jane ASMR 제인 [음식/요리/레시피]
# Nao FunFun [키즈/어린이]
# TWICE [음악/댄스/가수]
# DuDuPopTOY [키즈/어린이]
# Stone Music Entertainment [음악/댄스/가수]
# MBCkpop [TV/방송]
# 핑크퐁 (인기 동요・동화) [키즈/어린이]
# Larva TUBA [키즈/어린이]
# Toymong tv 토이몽TV [키즈/어린이]
# 서은이야기[SeoeunStory] [키즈/어린이]
# MBCentertainment [뉴스/정치/사회]
# Mnet Official [음악/댄스/가수]
# iKON [음악/댄스/가수]
# Hongyu ASMR 홍유 [음식/요리/레시피]
# MariAndKids [키즈/어린이]
# EXO [음악/댄스/가수]
# SonicToy소닉토이 [키즈/어린이]
# M2 [TV/방송]
# Sungha Jung [음악/댄스/가수]
# JTBC Entertainment [뉴스/정치/사회]
# Travel Thirsty [음식/요리/레시피]
# Serie A [해외]
# SEVENTEEN [음악/댄스/가수]
# ALL THE K-POP [음악/댄스/가수]
# ...

# %%
channel = channel_list[0]

for channel in channel_list :

    subscriber = channel.select('.subscriber_cnt')[0].text.strip()
    view = channel.select('.view_cnt')[0].text.strip()
    video = channel.select('.video_cnt')[0].text.strip()
    title = channel.select('h1 > a')[0].text.strip()
    category = channel.select('p.category')[0].text.strip()
    
    print(title, category,subscriber, view, video)
# Out:
# BLACKPINK [음악/댄스/가수] 5660만 148억2534만 336개
# Big Hit Labels [음악/댄스/가수] 5060만 143억1525만 525개
# BANGTANTV [음악/댄스/가수] 4420만 66억6690만 1,403개
# Boram Tube Vlog [보람튜브 브이로그] [키즈/어린이] 2650만 110억5288만 223개
# SMTOWN [음악/댄스/가수] 2600만 194억7205만 3,649개
# 1MILLION Dance Studio [음악/댄스/가수] 2320만 61억3179만 2,376개
# 1theK (원더케이) [음악/댄스/가수] 2180만 187억4701만 13,834개
# JYP Entertainment [음악/댄스/가수] 1980만 117억8673만 1,219개
# ArianaGrandeVevo [음악/댄스/가수] 1810만 159억1684만 129개
# Mnet K-POP [음악/댄스/가수] 1700만 111억9271만 22,599개
# JFlaMusic [음악/댄스/가수] 1680만 32억1466만 274개
# NBA [미분류] 1590만 79억2944만 34,499개
# KBS WORLD TV [TV/방송] 1540만 110억7069만 48,980개
# officialpsy [음악/댄스/가수] 1460만 81억8148만 90개
# BIGBANG [음악/댄스/가수] 1320만 62억6694만 773개
# CNN [뉴스/정치/사회] 1200만 91억3392만 150,492개
# Jane ASMR 제인 [음식/요리/레시피] 1140만 36억0529만 991개
# Nao FunFun [키즈/어린이] 1100만 625만 139개
# TWICE [음악/댄스/가수] 978만 12억1702만 496개
# DuDuPopTOY [키즈/어린이] 953만 41억5732만 1,581개
# Stone Music Entertainment [음악/댄스/가수] 942만 70억7094만 7,051개
# ...

# %%
#라이브러리 불러오기 
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
#크롬창 열기(최초 1회만 실행)
browser = webdriver.Chrome('c:/informs/chromedriver.exe')

# %%
url = "https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1"
browser.get(url)

html = browser.page_source
soup = BeautifulSoup(html,'html.parser') 
channel_list = soup.select('form > table > tbody > tr') 

for channel in channel_list :
    
    title = channel.select('h1 > a')[0].text.strip()
    category = channel.select('p.category')[0].text.strip()
    subscriber = channel.select('td.subscriber_cnt')[0].text.strip()
    view = channel.select('td.view_cnt')[0].text.strip()
    video = channel.select('td.video_cnt')[0].text.strip()
    
    print(title, category,subscriber, view, video, sep = ' / ')
    
#나중에 줄이 많아지면 전체 복수한다음에 반복문 안에서 탭해주기
# Out:
# BLACKPINK / [음악/댄스/가수] / 5660만 / 148억2534만 / 336개
# Big Hit Labels / [음악/댄스/가수] / 5060만 / 143억1525만 / 525개
# BANGTANTV / [음악/댄스/가수] / 4420만 / 66억6690만 / 1,403개
# Boram Tube Vlog [보람튜브 브이로그] / [키즈/어린이] / 2650만 / 110억5288만 / 223개
# SMTOWN / [음악/댄스/가수] / 2600만 / 194억7205만 / 3,649개
# 1MILLION Dance Studio / [음악/댄스/가수] / 2320만 / 61억3179만 / 2,376개
# 1theK (원더케이) / [음악/댄스/가수] / 2180만 / 187억4701만 / 13,834개
# JYP Entertainment / [음악/댄스/가수] / 1980만 / 117억8673만 / 1,219개
# ArianaGrandeVevo / [음악/댄스/가수] / 1810만 / 159억1684만 / 129개
# Mnet K-POP / [음악/댄스/가수] / 1700만 / 111억9271만 / 22,599개
# JFlaMusic / [음악/댄스/가수] / 1680만 / 32억1466만 / 274개
# NBA / [미분류] / 1590만 / 79억2944만 / 34,499개
# KBS WORLD TV / [TV/방송] / 1540만 / 110억7069만 / 48,980개
# officialpsy / [음악/댄스/가수] / 1460만 / 81억8148만 / 90개
# BIGBANG / [음악/댄스/가수] / 1320만 / 62억6694만 / 773개
# CNN / [뉴스/정치/사회] / 1200만 / 91억3392만 / 150,492개
# Jane ASMR 제인 / [음식/요리/레시피] / 1140만 / 36억0529만 / 991개
# Nao FunFun / [키즈/어린이] / 1100만 / 625만 / 139개
# ...
